# %% [markdown]
# <a href="https://colab.research.google.com/github/Yongyong-2/Quantum-Algorithm-Practice/blob/main/Day00_Colab_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Quantum!")
# Out:
# Hello Quantum!
